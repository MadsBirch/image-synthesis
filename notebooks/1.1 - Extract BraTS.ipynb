# %%
import nibabel as nib
import matplotlib.pyplot as plt
import numpy as np
import os

os.chdir("/Users/madsbirch/Documents/Thesis/code/image-synthesis/")

from src.data.make_brats import extract_brats_tar, preprocess_brats, train_val_split
import glob
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/madsbirch/Documents/Thesis/code/image-synthesis/notebooks/1.1 - Extract BraTS.ipynb Cell 1 line 6
#       <a href='vscode-notebook-cell:/Users/madsbirch/Documents/Thesis/code/image-synthesis/notebooks/1.1%20-%20Extract%20BraTS.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> import numpy as np
#       <a href='vscode-notebook-cell:/Users/madsbirch/Documents/Thesis/code/image-synthesis/notebooks/1.1%20-%20Extract%20BraTS.ipynb#W0sZmlsZQ%3D%3D?line=3'>4</a> import os
# ----> <a href='vscode-notebook-cell:/Users/madsbirch/Documents/Thesis/code/image-synthesis/notebooks/1.1%20-%20Extract%20BraTS.ipynb#W0sZmlsZQ%3D%3D?line=5'>6</a> from src.data.make_brats import extract_brats_tar, preprocess_brats, train_val_split
# ...

# %%
tar_path = "/Users/madsbirch/Data/Brats2021-Raw/BraTS2021_Training_Data.tar"
raw_data_path = "/Users/madsbirch/Documents/Thesis/code/image-synthesis/data/raw"
processed_data_path = "/Users/madsbirch/Documents/Thesis/code/image-synthesis/data/processed"
#extract_brats_tar(tar_path, raw_data_path)

# %%
modalities=['t1', 't2', 'flair']
preprocess_brats(raw_data_path, processed_data_path, modalities=modalities)
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/Users/madsbirch/miniforge3/envs/image_synth/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3526, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/dd/s080ztxj4q50zd2xnnx6t0t40000gn/T/ipykernel_15849/644402096.py", line 2, in <module>
#     preprocess_brats(raw_data_path, processed_data_path, modalities=modalities)
#   File "/Users/madsbirch/Documents/Thesis/code/image-synthesis/src/data/make_brats.py", line 55, in preprocess_brats
#   File "/Users/madsbirch/miniforge3/envs/image_synth/lib/python3.11/site-packages/nibabel/dataobj_images.py", line 373, in get_fdata
#     data = np.asanyarray(self._dataobj, dtype=dtype)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
glob.glob(os.path.join(processed_data_path, '*.nii.gz'))
# Out:
# ['/Users/madsbirch/Documents/Thesis/code/image-synthesis/data/processed/BraTS2021_01649.nii.gz',
#  '/Users/madsbirch/Documents/Thesis/code/image-synthesis/data/processed/BraTS2021_00698.nii.gz',
#  '/Users/madsbirch/Documents/Thesis/code/image-synthesis/data/processed/BraTS2021_01018.nii.gz',
#  '/Users/madsbirch/Documents/Thesis/code/image-synthesis/data/processed/BraTS2021_00303.nii.gz',
#  '/Users/madsbirch/Documents/Thesis/code/image-synthesis/data/processed/BraTS2021_00552.nii.gz',
#  '/Users/madsbirch/Documents/Thesis/code/image-synthesis/data/processed/BraTS2021_01583.nii.gz',
#  '/Users/madsbirch/Documents/Thesis/code/image-synthesis/data/processed/BraTS2021_00360.nii.gz',
#  '/Users/madsbirch/Documents/Thesis/code/image-synthesis/data/processed/BraTS2021_00540.nii.gz',
#  '/Users/madsbirch/Documents/Thesis/code/image-synthesis/data/processed/BraTS2021_00311.nii.gz',
#  '/Users/madsbirch/Documents/Thesis/code/image-synthesis/data/processed/BraTS2021_01177.nii.gz',
# ...

# %%
os.path.isdir('data')
# Out:
# True

# %%
os.makedirs('data2', 'raw')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/madsbirch/Documents/Thesis/code/image-synthesis/notebooks/1.1 - Extract BraTS.ipynb Cell 6 line 1
# ----> <a href='vscode-notebook-cell:/Users/madsbirch/Documents/Thesis/code/image-synthesis/notebooks/1.1%20-%20Extract%20BraTS.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> os.makedirs('data2', ['raw', 'processed'])
#
# File <frozen os>:225, in makedirs(name, mode, exist_ok)
#
# TypeError: 'list' object cannot be interpreted as an integer
